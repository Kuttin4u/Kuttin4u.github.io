# %%
# %matplotlib inline
# Dependencies and Setup
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load 
profit_loss = "client_data/Sept2010-Apr2011_Profit-Loss-Statement.csv"
daily_sales = "client_data/Sept2010-Apr2011_Daily-Sales-Records.csv"
cash_flow = "client_data/Sept2010-Apr2011_Cash-Flow-Statement.csv"

# Read data files
pl_data = pd.read_csv(profit_loss)
ds_data = pd.read_csv(daily_sales)
cf_data = pd.read_csv(cash_flow) 

#Display data
pl_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-71df60139dd0> in <module>
#      12
#      13 # Read data files
# ---> 14 pl_data = pd.read_csv(profit_loss, encoding="ISO-8859-1")
#      15 ds_data = pd.read_csv(daily_sales)
#      16 cf_data = pd.read_csv(cash_flow)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'client_data/Sept2010-Apr2011_Profit-Loss-Statement.csv' does not exist: b'client_data/Sept2010-Apr2011_Profit-Loss-Statement.csv'

# %%
# Combine the data into a single dataset
fin_statement_df = pd.merge(pl_data, ds_data, cf_data, how='right')


# Display the data table for preview
fin_statement_df.head()

# %%
# Obtain the x and y coordinates for each of the three city types
city_type = city_ride_df.groupby('type')
count_types =city_type['type'].count()
#city_type.head()
count_types.head()
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: type, dtype: int64

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
avg_fare =city_ride_df['fare'].mean()
rides_per = city_ride_df['ride_id'].count()
drivers = city_ride_df['driver_count'].count()


# Build the scatter plots for each city types
#plt.scatter(city_type,count_types,  marker="o", facecolors="Gold", edgecolors="black")

plt.scatter(rides_per, avg_fare, marker="o", label='Rural',s=10,facecolors="SkyBlue", edgecolors="black")
plt.scatter(rides_per, drivers, marker="o", label='Suburban',s=20,facecolors="Coral", edgecolors="black")
#plt.scatter(rides_per, city, marker="o", label='Urban',s=30,facecolors="Gold", edgecolors="black")

#city_ride_df.plot(kind='scatter', x=[count_types], y=[avg_fare])
    
# Incorporate the other graph properties
plt.title("Ride Sharing Data - August 18, 2019")
plt.xlabel("Number of Rides per City")
plt.ylabel("Average Fare")
plt.show()

# Create a legend
#legend = plt.legend(loc="lower right", scatterpoints=1, fontsize=8)
#legend.legendHandles[0]._sizes = [10]
#legend.legendHandles[1]._sizes = [10]

# Incorporate a text label regarding circle size

# Save Figure
plt.savefig("../RidesbyCityType.png")

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
type_percent = city_ride_df.groupby('type')
fares_by_type =type_percent['fare'].sum()
fares_by_type
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
# Calculate Type Percents
plt.title("Ride Percent by Type - August 18, 2019")
labels = ['Rural', 'Suburban', 'Urban']
fares = [4327.93, 19356.33, 39854.38]
colors = ['SkyBlue', 'Coral', "Gold"]
explode = (0,0,0.1)

# Build Pie Chart
plt.pie(fares, explode=explode, labels = labels, colors=colors, autopct="%1.1f%%", shadow=True,startangle=140)

# Save Figure
plt.savefig("../RidesbyTypePercent.png")

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
type_percent = city_ride_df.groupby('type')
rides_by_type =type_percent['ride_id'].count()
rides_by_type
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
plt.title("Ride Percent by Ride - August 18, 2019")
labels = ['Rural', 'Suburban', 'Urban']
rides = [125, 625, 1625]
colors = ['SkyBlue', 'Coral', "Gold"]
explode = (0,0,0.1)

# Build Pie Chart
plt.pie(rides, explode=explode, labels = labels, colors=colors, autopct="%1.1f%%", shadow=True,startangle=140)


# Save Figure
plt.savefig("../RidesbyRidePercent.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
type_percent = city_ride_df.groupby('type')
drivers_by_type =type_percent['driver_count'].sum()
drivers_by_type
# Out:
# type
# Rural         537
# Suburban     8570
# Urban       59602
# Name: driver_count, dtype: int64

# %%
# Calculate Driver Percents
plt.title("Ride Total by Driver - August 18, 2019")
labels = ['Rural', 'Suburban', 'Urban']
drivers = [537, 8570, 59602]
colors = ['SkyBlue', 'Coral', "Gold"]
explode = (0,0,0.1)

# Build Pie Chart
plt.pie(drivers, explode=explode, labels = labels, colors=colors, autopct="%1.1f%%", shadow=True,startangle=140)


# Save Figure
plt.savefig("../RidesbyTotalDrivers.png")

# %%
# Show Figure
plt.show()
